# %% [markdown]
# # Pandas Part 2 & Plotting

# %% [markdown]
# ## Agenda
# <br>
#
#     - Concatenating and merging pandas dataframes
#     - Introduction to making graphs/charts using Matplotlib and Pandas: Scatter, line, bar, boxplots, etc..
#     - Classwork exercises on plotting.

# %% [markdown]
# ### Concatenating Dataframes
#
# Concatenating is a complex way of saying you want to attach together two different objects, in case pandas data frame. In this part we'll be attaching dataframes top to bottom and side by side.

# %%
#Imports
import numpy as np
import pandas as pd

# %%
#Use numpy to create some data.

array1 = np.random.normal(loc = 5, size = (100, 3))
array2 = np.random.normal(loc = -5, size = (100, 3))

cols = ["feature_1", "feature_2", "feature_3"]

df1 = pd.DataFrame(array1, columns=cols)
df2 = pd.DataFrame(array2, columns=cols)

# %%
#View df1
df1.head()
# Out:
#    feature_1  feature_2  feature_3
# 0   6.617944   4.621930   4.501457
# 1   5.907594   5.564441   4.830488
# 2   4.791360   3.703904   5.838500
# 3   5.199807   8.184946   4.378521
# 4   6.085123   6.119366   5.038597

# %%
#View df2
df2.head()
# Out:
#    feature_1  feature_2  feature_3
# 0  -3.781673  -4.901845  -2.975521
# 1  -5.234516  -4.073827  -4.669284
# 2  -3.146103  -5.078509  -5.784109
# 3  -3.222067  -7.115717  -6.072671
# 4  -6.648430  -4.093620  -6.500935

# %% [markdown]
# We have two 100 x 3 dataframes and now we're going to concatenate along axis 0. Remember axis = 0/1?

# %%
#Call pandas concatenate method on df1 and df2

#The dataframes you want to concatenate must be organized into a list
list_of_dataframes = [df1, df2]
#Remeber axis = 0 is there, it's hidden but it's there.
data1 = pd.concat(list_of_dataframes)

#View concatenated dataframe which is 200 rows by 3 columns
data1
# Out:
#     feature_1  feature_2  feature_3
# 0    6.617944   4.621930   4.501457
# 1    5.907594   5.564441   4.830488
# 2    4.791360   3.703904   5.838500
# 3    5.199807   8.184946   4.378521
# 4    6.085123   6.119366   5.038597
# 5    5.332639   5.527225   5.725320
# 6    4.109112   4.095696   4.749755
# 7    5.443471   6.056915   7.820823
# 8    3.054490   3.850899   3.303384
# 9    6.161656   5.350513   5.830620
# 10   5.158268   4.332613   4.624630
# 11   4.657421   5.928940   2.942219
# 12   5.374624   6.631232   4.822255
# 13   6.208297   4.216354   3.992013
# 14   5.765131   3.687660   3.447142
# 15   4.574546   4.195355   4.712116
# 16   4.964909   5.361124   4.939638
# 17   3.996111   5.650857   5.100281
# 18   3.786410   3.590713   3.883578
# 19   6.260928   3.445316   5.716378
# 20   4.244765   5.213382   5.397262
# 21   5.467119   3.668998   3.742349
# 22   4.365901   5.255118   5.006679
# 23   4.741052   5.247393   5.233065
# 24   4.645417   4.904070   5.904871
# 25   3.172941   5.479926   5.851927
# 26   5.078712   3.780303   4.393039
# 27   2.879064   3.362156   4.416846
# 28   6.891161   3.264685   4.432681
# 29   5.256444   3.932738   4.879465
# ..        ...        ...        ...
# 70  -4.607008  -5.359863  -5.056608
# 71  -4.353674  -5.164504  -3.760570
# 72  -6.588239  -4.306820  -3.152824
# 73  -5.000453  -4.612476  -4.464836
# 74  -5.053593  -5.010313  -5.483940
# 75  -4.313088  -4.998884  -6.546542
# 76  -4.596335  -4.699286  -4.747439
# 77  -6.112485  -5.486623  -3.450934
# 78  -4.199789  -3.373501  -4.996180
# 79  -5.600925  -5.507659  -6.049292
# 80  -6.189041  -5.006993  -5.894665
# 81  -4.895192  -4.071911  -4.303329
# 82  -4.647854  -5.610741  -6.451887
# 83  -6.091494  -5.253738  -4.505681
# 84  -2.857108  -5.027397  -5.555567
# 85  -5.316491  -4.308176  -5.537611
# 86  -5.831623  -6.593453  -3.425431
# 87  -4.842170  -2.659104  -5.608818
# 88  -5.460924  -3.508842  -4.424614
# 89  -5.834744  -5.951975  -5.921099
# 90  -3.903971  -7.599121  -5.298514
# 91  -4.458812  -5.062990  -4.816784
# 92  -5.389288  -6.034913  -4.423848
# 93  -5.102533  -5.542636  -4.945301
# 94  -5.904610  -3.772497  -4.273726
# 95  -4.378773  -4.001647  -6.078321
# 96  -4.556753  -3.865278  -4.733068
# 97  -4.504861  -5.817486  -4.906937
# 98  -3.987512  -4.227118  -5.998230
# 99  -6.266809  -4.981669  -3.937765
#
# [200 rows x 3 columns]

# %% [markdown]
# There is an issue here? What is it?

# %% [markdown]
# We have duplicate index values!

# %%
#We can reset the index
data1.reset_index()
# Out:
#      index  feature_1  feature_2  feature_3
# 0        0   6.617944   4.621930   4.501457
# 1        1   5.907594   5.564441   4.830488
# 2        2   4.791360   3.703904   5.838500
# 3        3   5.199807   8.184946   4.378521
# 4        4   6.085123   6.119366   5.038597
# 5        5   5.332639   5.527225   5.725320
# 6        6   4.109112   4.095696   4.749755
# 7        7   5.443471   6.056915   7.820823
# 8        8   3.054490   3.850899   3.303384
# 9        9   6.161656   5.350513   5.830620
# 10      10   5.158268   4.332613   4.624630
# 11      11   4.657421   5.928940   2.942219
# 12      12   5.374624   6.631232   4.822255
# 13      13   6.208297   4.216354   3.992013
# 14      14   5.765131   3.687660   3.447142
# 15      15   4.574546   4.195355   4.712116
# 16      16   4.964909   5.361124   4.939638
# 17      17   3.996111   5.650857   5.100281
# 18      18   3.786410   3.590713   3.883578
# 19      19   6.260928   3.445316   5.716378
# 20      20   4.244765   5.213382   5.397262
# 21      21   5.467119   3.668998   3.742349
# 22      22   4.365901   5.255118   5.006679
# 23      23   4.741052   5.247393   5.233065
# 24      24   4.645417   4.904070   5.904871
# 25      25   3.172941   5.479926   5.851927
# 26      26   5.078712   3.780303   4.393039
# 27      27   2.879064   3.362156   4.416846
# 28      28   6.891161   3.264685   4.432681
# 29      29   5.256444   3.932738   4.879465
# ..     ...        ...        ...        ...
# 170     70  -4.607008  -5.359863  -5.056608
# 171     71  -4.353674  -5.164504  -3.760570
# 172     72  -6.588239  -4.306820  -3.152824
# 173     73  -5.000453  -4.612476  -4.464836
# 174     74  -5.053593  -5.010313  -5.483940
# 175     75  -4.313088  -4.998884  -6.546542
# 176     76  -4.596335  -4.699286  -4.747439
# 177     77  -6.112485  -5.486623  -3.450934
# 178     78  -4.199789  -3.373501  -4.996180
# 179     79  -5.600925  -5.507659  -6.049292
# 180     80  -6.189041  -5.006993  -5.894665
# 181     81  -4.895192  -4.071911  -4.303329
# 182     82  -4.647854  -5.610741  -6.451887
# 183     83  -6.091494  -5.253738  -4.505681
# 184     84  -2.857108  -5.027397  -5.555567
# 185     85  -5.316491  -4.308176  -5.537611
# 186     86  -5.831623  -6.593453  -3.425431
# 187     87  -4.842170  -2.659104  -5.608818
# 188     88  -5.460924  -3.508842  -4.424614
# 189     89  -5.834744  -5.951975  -5.921099
# 190     90  -3.903971  -7.599121  -5.298514
# 191     91  -4.458812  -5.062990  -4.816784
# 192     92  -5.389288  -6.034913  -4.423848
# 193     93  -5.102533  -5.542636  -4.945301
# 194     94  -5.904610  -3.772497  -4.273726
# 195     95  -4.378773  -4.001647  -6.078321
# 196     96  -4.556753  -3.865278  -4.733068
# 197     97  -4.504861  -5.817486  -4.906937
# 198     98  -3.987512  -4.227118  -5.998230
# 199     99  -6.266809  -4.981669  -3.937765
#
# [200 rows x 4 columns]

# %% [markdown]
# Concatenate dataframes along axis 1 aka attach dataframes side by side.

# %%
#Change column names of df2 so we avoid duplication issue
df2.columns = ["feature_4", "feature_5", "feature_6"]
df2.head()
# Out:
#    feature_4  feature_5  feature_6
# 0  -3.781673  -4.901845  -2.975521
# 1  -5.234516  -4.073827  -4.669284
# 2  -3.146103  -5.078509  -5.784109
# 3  -3.222067  -7.115717  -6.072671
# 4  -6.648430  -4.093620  -6.500935

# %%
#Make list of dataframes
dflist = [df1, df2]

#Concatenate dataframes but this time set axis = 1
data2 = pd.concat(dflist, axis = 1)

#View concatenated dataframe which 100 rows by 4 columns

data2
# Out:
#     feature_1  feature_2  feature_3  feature_4  feature_5  feature_6
# 0    6.617944   4.621930   4.501457  -3.781673  -4.901845  -2.975521
# 1    5.907594   5.564441   4.830488  -5.234516  -4.073827  -4.669284
# 2    4.791360   3.703904   5.838500  -3.146103  -5.078509  -5.784109
# 3    5.199807   8.184946   4.378521  -3.222067  -7.115717  -6.072671
# 4    6.085123   6.119366   5.038597  -6.648430  -4.093620  -6.500935
# 5    5.332639   5.527225   5.725320  -4.628740  -4.024000  -4.079063
# 6    4.109112   4.095696   4.749755  -5.965894  -4.570158  -5.344209
# 7    5.443471   6.056915   7.820823  -5.080523  -4.975562  -4.032171
# 8    3.054490   3.850899   3.303384  -4.895526  -5.426374  -6.212072
# 9    6.161656   5.350513   5.830620  -5.211031  -5.995536  -4.628979
# 10   5.158268   4.332613   4.624630  -5.982876  -3.331380  -2.913673
# 11   4.657421   5.928940   2.942219  -3.755014  -3.980345  -4.001812
# 12   5.374624   6.631232   4.822255  -4.842496  -6.920432  -6.016713
# 13   6.208297   4.216354   3.992013  -4.642190  -5.135397  -5.173132
# 14   5.765131   3.687660   3.447142  -4.002995  -5.077879  -7.591245
# 15   4.574546   4.195355   4.712116  -5.513083  -5.298032  -7.469447
# 16   4.964909   5.361124   4.939638  -4.104415  -5.225323  -4.180159
# 17   3.996111   5.650857   5.100281  -5.006175  -5.437213  -5.634247
# 18   3.786410   3.590713   3.883578  -6.936372  -5.942548  -4.135620
# 19   6.260928   3.445316   5.716378  -5.103247  -2.828998  -5.543497
# 20   4.244765   5.213382   5.397262  -5.812486  -6.309749  -5.643483
# 21   5.467119   3.668998   3.742349  -4.507943  -5.186835  -5.250043
# 22   4.365901   5.255118   5.006679  -5.445747  -6.454998  -3.608934
# 23   4.741052   5.247393   5.233065  -6.205309  -5.029459  -6.121790
# 24   4.645417   4.904070   5.904871  -4.580034  -6.114274  -5.431625
# 25   3.172941   5.479926   5.851927  -4.397791  -4.406091  -6.014664
# 26   5.078712   3.780303   4.393039  -4.653725  -5.218619  -5.772687
# 27   2.879064   3.362156   4.416846  -7.146022  -5.412833  -3.826616
# 28   6.891161   3.264685   4.432681  -4.443756  -4.745484  -5.974576
# 29   5.256444   3.932738   4.879465  -5.631111  -4.336001  -5.617895
# ..        ...        ...        ...        ...        ...        ...
# 70   5.051086   2.642132   4.876451  -4.607008  -5.359863  -5.056608
# 71   4.069447   2.579548   5.857531  -4.353674  -5.164504  -3.760570
# 72   3.827545   4.957050   4.802137  -6.588239  -4.306820  -3.152824
# 73   5.491361   3.451355   4.311159  -5.000453  -4.612476  -4.464836
# 74   7.159612   4.535367   3.518161  -5.053593  -5.010313  -5.483940
# 75   6.308635   4.974663   6.101455  -4.313088  -4.998884  -6.546542
# 76   4.271897   4.129788   4.740714  -4.596335  -4.699286  -4.747439
# 77   5.359680   3.333016   3.635143  -6.112485  -5.486623  -3.450934
# 78   3.559491   6.347395   5.470464  -4.199789  -3.373501  -4.996180
# 79   5.260125   7.294382   3.164450  -5.600925  -5.507659  -6.049292
# 80   4.730246   5.206520   5.781387  -6.189041  -5.006993  -5.894665
# 81   4.947262   6.481574   5.632282  -4.895192  -4.071911  -4.303329
# 82   4.701478   5.213639   6.145783  -4.647854  -5.610741  -6.451887
# 83   5.750239   4.254927   3.611290  -6.091494  -5.253738  -4.505681
# 84   3.989607   4.021563   4.681106  -2.857108  -5.027397  -5.555567
# 85   6.238879   4.268579   4.153289  -5.316491  -4.308176  -5.537611
# 86   5.615807   4.992851   5.677261  -5.831623  -6.593453  -3.425431
# 87   5.485722   6.146230   4.303341  -4.842170  -2.659104  -5.608818
# 88   4.541667   6.685880   4.099625  -5.460924  -3.508842  -4.424614
# 89   5.112263   5.360302   6.910061  -5.834744  -5.951975  -5.921099
# 90   5.279556   3.091012   6.051012  -3.903971  -7.599121  -5.298514
# 91   5.876497   4.556739   5.487229  -4.458812  -5.062990  -4.816784
# 92   4.744239   5.046693   3.801868  -5.389288  -6.034913  -4.423848
# 93   5.418029   6.415263   7.841748  -5.102533  -5.542636  -4.945301
# 94   6.420959   3.625513   5.467712  -5.904610  -3.772497  -4.273726
# 95   5.127016   3.991396   4.141800  -4.378773  -4.001647  -6.078321
# 96   4.902319   6.070191   5.099866  -4.556753  -3.865278  -4.733068
# 97   4.259331   4.174424   5.126295  -4.504861  -5.817486  -4.906937
# 98   3.712717   4.467892   4.269388  -3.987512  -4.227118  -5.998230
# 99   3.988329   5.028175   5.086330  -6.266809  -4.981669  -3.937765
#
# [100 rows x 6 columns]

# %% [markdown]
# ### Merging Dataframes
#
# Similar to SQL joins, we'll combine two DataFrames using a unique ID found in both DataFrames.

# %%
#Create sample dataframes
A = pd.DataFrame({'color': ['green', 'yellow', 'red'], 'num':[1, 2, 3]})
A
# Out:
#     color  num
# 0   green    1
# 1  yellow    2
# 2     red    3

# %%
B = pd.DataFrame({'color': ['green', 'yellow', 'pink'], 'size':['S', 'M', 'L']})
B
# Out:
#     color size
# 0   green    S
# 1  yellow    M
# 2    pink    L

# %% [markdown]
# Inner join: Only include observations found in both A and B:

# %%
#Use pd.merge to do join. Set how = "inner"
pd.merge(A, B, how='inner')
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M

# %%
#Does the same thing
pd.merge(A, B, how='inner', on="color")
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M

# %% [markdown]
# If you don't set column to do the join on, then pandas will use the shared column. In this example, the shared column is "color".

# %% [markdown]
# Outer join: Include observations found in either A or B:

# %%
#Set how = "outer"
pd.merge(A, B, how='outer')
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2     red  3.0  NaN
# 3    pink  NaN    L

# %% [markdown]
# Left join: Include all observations found in A:

# %%
#Set how = "left"
pd.merge(A, B, how='left')
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M
# 2     red    3  NaN

# %% [markdown]
# Right join: Include all observations found in B:

# %%
pd.merge(A, B, how='right')
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2    pink  NaN    L

# %% [markdown]
# Another example

# %%
#Make dataframes from dictionaries
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}


data1 = pd.DataFrame(raw_data_1, columns = ['subject_id', 'first_name', 'last_name'])
data2 = pd.DataFrame(raw_data_2, columns = ['subject_id', 'first_name', 'last_name'])
data3 = pd.DataFrame(raw_data_3, columns = ['subject_id','test_id'])

data3
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %%
#Concatenate data1 and data2 on axis 0 assign it to all_data
all_data = pd.concat([data1, data2], axis = 0)

#Inner join all_data and data on the subject_id column
pd.merge(all_data, data3, on='subject_id')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15

# %% [markdown]
# ### Exercise time
#
# 1. Merge only the data that has the same 'subject_id' on both data1 and data2
#
# 2. Merge all values in data1 and data2, with matching records from both sides where available.

# %%
#Answer 1 
pd.merge(data1, data2, on='subject_id', how='inner')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %%
#Answer 2
pd.merge(data1, data2, on='subject_id', how='outer')
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
# 5          6          NaN         NaN         Bran     Balwner
# 6          7          NaN         NaN        Bryce       Brice
# 7          8          NaN         NaN        Betty      Btisan

# %% [markdown]
# ### More resources concatenating, merging, and other ways to transforms data in pandas.
#
# http://www.datacarpentry.org/python-ecology-lesson/04-merging-data/
# https://github.com/shanealynn/Pandas-Merge-Tutorial/blob/master/Pandas%20Merge%20Tutorial.ipynb
# https://www.shanelynn.ie/merge-join-dataframes-python-pandas-index-1/
# https://pythonprogramming.net/concatenate-append-data-analysis-python-pandas-tutorial/
# https://www.dezyre.com/data-science-in-python-tutorial/pandas-introductory-tutorial-part-3
#
# Pivot tables: http://pbpython.com/pandas-pivot-table-explained.html

# %% [markdown]
# ## Plotting

# %%
#import plotting library
import matplotlib.pyplot as plt
#Don't forget this part!
# %matplotlib inline

# %%
#Make some random numpy arays

a = np.random.rand(100)
b = np.random.rand(100)*3 + 2

# %% [markdown]
# Line plots

# %%
#Use .plot() to make a line plot with a
plt.plot(a)
plt.show()

# %%
#Change color
plt.plot(b, c="g")
plt.show()

# %%
#Change thickness of the line
plt.plot(a, linewidth = 4)
plt.show()

# %%
#Change opaqueness of plot. Scale is 0.0-1.0.
#1.0 is opaque
#0.0 is transparent
plt.plot(b, alpha=.5)
plt.show()

# %% [markdown]
# 1. Adjust size of plot
# 2. Add some context to the plot

# %%
#Set plot size to 8x6 
plt.figure(figsize=(8,6))

#Call plot with linewidth to 3
plt.plot(a,linewidth=3)

#Label the x-axis
plt.xlabel("This is the X-axis",)

#Label the y-axis
plt.ylabel("This is the Y-axis")

#Give the plot a title
plt.title("This is our fantastic plot")

plt.show()

# %% [markdown]
# We can combine charts together on a single plot

# %%
plt.plot(a, c= "r")
plt.plot(b, c= "g")

plt.show()

# %% [markdown]
# Or we can put display this using subplots

# %%
plt.figure(figsize=(12,4))
plt.subplot(1, 2, 1,)
plt.plot(a, color='purple')
plt.ylabel('Values')
plt.title('Random Plot 1')

plt.subplot(1, 2, 2)
plt.plot(b, color='green')
plt.ylabel('Values')
plt.title('Random Plot 2')

#tight_layout() adds spacing between plots
plt.tight_layout()
plt.show()

# %% [markdown]
# Scatter plots

# %%
#Plot a vs b using a scatter plot
#Adjust size
plt.figure(figsize=(8, 5))

#Call .scatter() method. Set s= 30 to increase size of plot.
plt.scatter(a, b, s=30)

#Label x and y axes
plt.xlabel("A array")
plt.ylabel("B array")
plt.show()

# %%
#Lets call same plot but let's impose some limits on it

plt.figure(figsize=(8, 5))

#Call .scatter() method. Set s= 30 to increase size of plot.
plt.scatter(a, b, s=30)

#Label x and y axes
plt.xlabel("A array")
plt.ylabel("B array")

#Limits on both axes
plt.xlim(0.2, 0.8)
plt.ylim(2.5, 4.0)
plt.show()

# %% [markdown]
# Change the size and color of individual dots

# %%
#Create numpy array of sizes
sizes = np.random.random(100)*200

#Create numpy array of colors randomly selected from color_list a 100 times
f

# %% [markdown]
# Pass sizes and colors in to scatter plot function

# %%
plt.figure(figsize=(8, 5))

#Set s to sizes and c to colors
plt.scatter(a, b, s=sizes, c=colors)

plt.xlabel("A array")
plt.ylabel("B array")
plt.show()

# %% [markdown]
# Voila! We have a colorful scatter plot of with dots of varying sizes
#
# However let's try making it look a little nicer.

# %%
#Load in the fivethirtyeight plot style
plt.style.use("fivethirtyeight")

# %%
#Let's run our scatter plot again
plt.figure(figsize=(8, 5))
plt.scatter(a, b, s=sizes, c=colors)
plt.xlabel("A array")
plt.ylabel("B array")
plt.show()

# %% [markdown]
# Bar plots

# %%
#Lists of seasons and average high temperature for San Francisco
seasons = ["Spring", "Summer", "Fall", "Winter"]
sf_temps = [64, 68, 63, 59]

# %%
#Plot bar plot of temperatures on y axis and season on x axis

#Requires a list of integers to be used as position coordinates
pos = np.arange(len(seasons))

#Set bar width
w = 0.4
plt.bar(left=pos, width=w, height=sf_temps,tick_label=seasons, align="center")
plt.show()

# %%
#Same chart but with horizontal orientation

plt.barh(bottom = pos, width = sf_temps, height=w, tick_label=seasons, align="center")
plt.show()

# %% [markdown]
# Compare San Francisco to Los Angeles and New York

# %%
#List of temperatures for LA and NY
la_temps = [73, 87, 74, 62]
ny_temps = [58, 85, 53, 39]

# %%
#Plot all three cities together on same plot

w = 0.2
#Bar plot number 1: San Francisco

#Shift positioning to the left by width value
plt.bar(pos-w, width=w, height=sf_temps, align="center")

#Bar plot number 2: Los Angeles
#Keep pos the same
#The middle chart gets the tick_label
plt.bar(pos, width=w, height=la_temps, color="r", tick_label=seasons, align = "center")

#Bar plot number 3: New York
#Shift positioning to the right by width value
plt.bar(pos + w, width=w, height=ny_temps, color = "g", align = "center")

plt.ylabel("Average Temperatures")
#Set a legend. bbox_to_anchor moves legend out of the way
plt.legend(["San Francisco", "Los Angeles", "New York"],
          fontsize="small",
          bbox_to_anchor=(1.4, .95))
plt.show()

# %% [markdown]
# ### Statistical plots

# %% [markdown]
# Histograms

# %%
#Create numpy array with a normal distribution of 3000 values, mean 10, and std of 3
a = np.random.normal(loc=10,size=3000, scale=3)

# %%
#Make a histogram of a

plt.hist(a)
plt.show()

# %% [markdown]
# Shows data actually is a normal distribution

# %% [markdown]
# Let's make some changes

# %%
#Set bins = 20 and normed=True

plt.hist(a, bins = 20, normed=True)
plt.show()

# %% [markdown]
# What is the difference?

# %% [markdown]
# Lets show two histograms on the same plot

# %%
b
# Out:
# array([ 2.22354112,  4.06481226,  2.55980283,  4.6343727 ,  3.05996241,
#         2.33266025,  2.60474632,  4.97819097,  3.77881454,  4.95103344,
#         4.06634476,  4.45530749,  4.11422835,  3.33034857,  3.20529113,
#         2.57486286,  4.85965095,  3.04300797,  2.52238311,  4.94143382,
#         2.52938219,  3.34436571,  3.21679091,  2.24098444,  4.70583549,
#         4.82825255,  3.63190389,  4.46439152,  2.32604391,  4.99368184,
#         3.18137775,  2.15182203,  3.58826216,  3.28789583,  2.99844477,
#         2.47739952,  3.23011335,  3.56765737,  4.67836154,  3.62545713,
#         4.53040727,  4.11060898,  2.96481369,  4.82952586,  3.89246524,
#         2.4509708 ,  3.41055334,  2.1032459 ,  2.33173282,  2.96315665,
#         2.51242632,  2.08964792,  2.71368065,  2.69334563,  4.21884949,
#         4.84898744,  2.65915864,  4.52572953,  3.33625075,  4.49959144,
#         4.33255576,  2.44070349,  4.47531898,  4.85835165,  2.14883665,
#         3.71769698,  2.73768957,  3.47123011,  2.82417724,  2.27053678,
#         3.29420362,  3.21376845,  2.53612619,  2.92760973,  2.1766023 ,
#         4.78679437,  2.59299949,  4.09186707,  2.96196941,  2.13457882,
#         3.32669362,  4.53700837,  2.9714126 ,  4.50049528,  2.65491714,
#         4.80590842,  2.90456702,  3.18212562,  3.98437563,  2.90273956,
#         4.65145389,  3.82815387,  3.99728036,  4.33668428,  2.20987835,
#         4.68792199,  2.80916455,  2.78218905,  4.22779568,  4.27019484])

# %%
#Create another numpy array but this time with a gamma distribution

b = np.random.normal(loc=5,size=3000, scale=1)
#Call hist on a and b. Uses bins =50 for both.
#Use different colors for both plots
plt.figure(figsize=(9, 8))
plt.hist(a, bins=50, color="red", alpha= .6)
plt.hist(b, bins=50, alpha = .6)
plt.show()

# %% [markdown]
# Compare and contrast the two plots

# %% [markdown]
# #### Boxplots

# %%
#Set random seed so we all generate the same random data data
np.random.seed(42)
# Sample data.
x = np.random.normal(10, 5, 1000)
# Generate and display the box plot.
plt.boxplot(x)
plt.show()

# %% [markdown]
# - The box in the boxplot represents the middle 50% of values, all the values between the 25th and 75th percentile. Aka the interquartile range "IQR". The red line represents the median.
#
# - The whiskers will extend up and down up to a distance of 1.5x the IQR away from the top and bottom of the box. If all values are within that range, the whiskers will go to the max and min of the variable.

# %% [markdown]
# <b> Which do you think is better for showing the distribution of a set of numbers? Boxplot or histogram? Why?<b>

# %% [markdown]
# ### Plotting with Pandas
# <br>
# We can create charts directly from pandas dataframes and series. Let's find out how to do so with pokemon data!
#
# Data source:https://www.kaggle.com/abcsds/pokemon

# %%
#Data path
path  = "../data/Pokemon.csv"

#Load pokemon data into a pandas dataframe
pm = pd.read_csv(path)
pm.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#Clean up the columns by lowercasing them and getting rid spaces and periods
pm.columns = pm.columns.str.lower().str.replace(" ", "_").str.replace(".", "_")
pm.head()
# Out:
#    #                   name type_1  type_2  total  hp  attack  defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    sp__atk  sp__def  speed  generation  legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#Drop the hashtag column from data
pm.drop("#", axis=1, inplace=True)

# %% [markdown]
# Use can matplotlib on pandas data

# %%
plt.hist(pm.total)
plt.show()

# %% [markdown]
# But we're going to use the built-in plotting functionality of pandas.

# %%
#Same graph as above but using pandas

pm.total.plot(kind="hist")
plt.show()

# %% [markdown]
# Make a histogram of all the numerical columns in the data

# %%
#Call .hist() on pm and drop 
pm.hist(figsize=(12,9))
plt.tight_layout()
plt.show()

# %% [markdown]
# Pandas bar plots

# %%
#Assign pm.type_1 to poke_type
poke_type = pm.type_1

# %% [markdown]
# Use a bar plot to visualize the counts of the various types of pokemon.

# %%
#Use value_counts to get the tallies of the types and assign to type_vc

type_vc = poke_type.value_counts()

#Call .plot on type_vc and set kind = "bar"

type_vc.plot(kind="bar")
plt.tight_layout()
plt.show()

# %% [markdown]
# Let's try this again but with some adjustments

# %%
#Set kind = "barh" to make it a horizontal plot
#Set figsize= (8, 5) to adjust size
#Set color = "g"
#Set alpha = 0.6
#Set width = 1
type_vc.plot(kind="barh", figsize=(8,5), color="g", width = 1)
plt.show()

# %% [markdown]
# Pandas scatter plots

# %%
#View data
pm.head()
# Out:
#                     name type_1  type_2  total  hp  attack  defense  sp__atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    sp__def  speed  generation  legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# Let's visualize attack vs defense

# %%
#Specify column names for the x and y axes
#Set kind = "scatter"
pm.plot(x="defense", y = "attack", kind="scatter")
plt.show()

# %% [markdown]
# What is the relationship between the two attributes?

# %% [markdown]
# Let's colorify the plot!

# %%
#Same code as before but this time specify 
pm.plot(x="defense", y = "attack", kind="scatter", c="legendary", figsize=(10, 7))
plt.show()

# %% [markdown]
# What is the difference between legendary and non-legendary pokemon when it comes to attack and defense?

# %%
pm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# name          800 non-null object
# type_1        800 non-null object
# type_2        414 non-null object
# total         800 non-null int64
# hp            800 non-null int64
# attack        800 non-null int64
# defense       800 non-null int64
# sp__atk       800 non-null int64
# sp__def       800 non-null int64
# speed         800 non-null int64
# generation    800 non-null int64
# legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.6+ KB

# %% [markdown]
# Specify our own color

# %%
#Create color dictionary, which we'll use to map over the pandas series. 
#Convert False to yellow and True to green
color_dict = {False:"y", True:"g"}

#Create new pandas series object which is the legendary column but with color-encoding
colors = pm.legendary.map(color_dict)

# %%
#Scatter with new color encoding
pm.plot(x="defense", y = "attack", kind="scatter", c=colors, figsize=(10, 7))
plt.show()

# %% [markdown]
# Let's try a similar plot but this time we'll use point size to visualize the speed of the pokemon

# %%
#Set s = pm.speed
pm.plot(x="defense", y = "attack", kind="scatter",alpha=.4, s=pm.speed, figsize=(10, 7))
plt.show()

# %% [markdown]
# Combine both of the previous two plots into one

# %%
pm.plot(x="defense", y = "attack", kind="scatter",alpha=.4, s=pm.speed, c=colors, figsize=(10, 7))
plt.show()

# %% [markdown]
# ### Grouped plot: boxes and bars

# %% [markdown]
# Grouped box plots

# %%
#Use pandas to make box plot of a single column
pm.total.plot(kind="box")
plt.show()

# %%
#Box plot of attack points grouped by type_1
#Column is set equal to the continuous variable we wish to display
#By is set equal to the categorical variable that determines the various individual boxplots
plt.figure(figsize=(8, 8))
pm.boxplot(column="total", by="generation")
plt.tight_layout()
plt.show()

# %%
pm.head()
# Out:
#                     name type_1  type_2  total  hp  attack  defense  sp__atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    sp__def  speed  generation  legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# Grouped bar plots

# %%
#List of columns to use for this exercise
cols = ["hp", "attack", "defense"]

# %%
#Group by generation
#Pass in cols
#Call .mean()
#Call .plot() with bar plot and size of 10x8
pm.groupby("generation")[cols].mean().plot(kind="bar", figsize=(10,8), 
                                           title = "Grouped Bar plots")
plt.show()

# %% [markdown]
# Stack 'em

# %%
pm.groupby("generation")[cols].mean().plot(kind="bar",stacked=True, figsize=(10,8),
                                          title="Stacked Bar Plots")
#Move legend box to center right
plt.legend(loc="right")
plt.show()

# %% [markdown]
# ## More resources on plotting in Python
#
# https://github.com/matplotlib/AnatomyOfMatplotlib/blob/master/AnatomyOfMatplotlib-Part1-Figures_Subplots_and_layouts.ipynb
#
# https://github.com/rasbt/matplotlib-gallery/tree/master/ipynb
#
# https://github.com/jbwhit/jupyter-tips-and-tricks/tree/master/notebooks
# <br><br>
# From [PythonDataScienceHandbook](https://github.com/jakevdp/PythonDataScienceHandbook):
#  - https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.00-Introduction-To-Matplotlib.ipynb
#  - https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.01-Simple-Line-Plots.ipynb
#  - https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.02-Simple-Scatter-Plots.ipynb
#  - https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.05-Histograms-and-Binnings.ipynb
#  - https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.04-Density-and-Contour-Plots.ipynb
#
#
#
# Check out the matplotlib cheat sheet in the extracurricular directory.

# %% [markdown]
# ## Class exercise
#
# Pick out a dataset from the data directory and explore it as much as possible using the visualizations we just learned. I want this to be a freeform exercise where you go out in the wild and explore on your own.
#
# You can choose any dataset you like but I recommend:
# - auto-mpg
# - red_wine_quality
# - simple_demographics
# - movie_metadata
# - drinks
#
# Everytime you make visualization, I want you to guess what you are going to see. Make an expectation and then see if you're proven wrong or right.
#
# Explore:
#     - The distributions of certain features (Histograms and bar plots)
#     - Use bar plots to count categorical data
#     - Relationships between different features. Do those relationships change when apply certain conditions
