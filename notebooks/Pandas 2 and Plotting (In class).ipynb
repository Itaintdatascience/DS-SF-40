# %% [markdown]
# # Pandas Part 2 & Plotting

# %% [markdown]
# ## Agenda
# <br>
#
#     - Concatenating and merging pandas dataframes
#     - Introduction to making graphs/charts using Matplotlib and Pandas: Scatter, line, bar, boxplots, etc..
#     - Classwork exercises on plotting.

# %% [markdown]
# ### Concatenating Dataframes
#
# Concatenating is a complex way of saying you want to attach together two different objects, in case pandas data frame. In this part we'll be attaching dataframes top to bottom and side by side.

# %%
#Imports
import numpy as np
import pandas as pd

# %%
#Use numpy to create some data.
array1 = np.random.normal(loc = 5, size = (100, 3))
array2 = np.random.normal(loc = -5, size = (100, 3))

#Creat column names
cols = ["feature_1", "feature_2", "feature_3"]

#Feed arrays and cols into dataframes
df1 = pd.DataFrame(array1, columns=cols)
df2 = pd.DataFrame(array2, columns=cols)

# %%
#View df1
df1.head()
# Out:
#    feature_1  feature_2  feature_3
# 0   4.550507   5.004117   5.210501
# 1   5.214715   5.721761   6.735769
# 2   4.824738   4.032436   4.419802
# 3   4.018777   2.726202   2.457787
# 4   3.876723   4.054230   6.267056

# %%
#View df2
df2.head()
# Out:
#    feature_1  feature_2  feature_3
# 0  -4.763054  -6.406415  -7.118273
# 1  -5.995944  -4.872129  -3.334770
# 2  -4.673589  -6.013035  -4.856640
# 3  -5.242724  -4.759708  -4.689278
# 4  -2.567967  -4.729315  -5.523268

# %% [markdown]
# We have two 100 x 3 dataframes and now we're going to concatenate along axis 0. Remember axis = 0/1?

# %%
#Call pandas concatenate method on df1 and df2

#The dataframes you want to concatenate must be organized into a list
list_of_dataframes = [df1, df2]
#Remeber axis = 0 is there, it's hidden but it's there.
data1 = pd.concat(list_of_dataframes)

#View concatenated dataframe which is 200 rows by 3 columns
data1
# Out:
#     feature_1  feature_2  feature_3
# 0    4.550507   5.004117   5.210501
# 1    5.214715   5.721761   6.735769
# 2    4.824738   4.032436   4.419802
# 3    4.018777   2.726202   2.457787
# 4    3.876723   4.054230   6.267056
# 5    4.839432   5.513151   4.915874
# 6    4.621005   4.312721   5.390580
# 7    5.029286   5.236494   3.800252
# 8    5.473726   5.434129   6.984428
# 9    5.000643   4.985643   4.702337
# 10   6.104494   4.898955   4.509896
# 11   3.821223   4.918051   3.977788
# 12   4.586813   4.444995   6.229879
# 13   5.229213   6.982055   5.359106
# 14   5.427002   4.917086   6.227721
# 15   5.454848   3.331649   4.293668
# 16   4.712216   5.670613   5.476897
# 17   4.325281   4.913907   5.649319
# 18   4.888530   5.417880   6.992144
# 19   2.432764   4.836896   5.292530
# 20   6.304912   6.358224   6.171997
# 21   4.550257   5.830858   2.754417
# 22   6.356579   6.939571   4.600550
# 23   8.001308   7.220978   3.111329
# 24   4.871987   5.208729   5.512565
# 25   4.734293   3.335230   5.279084
# 26   4.400667   6.239742   4.844260
# 27   3.919119   4.814754   5.610985
# 28   3.559219   5.075045   6.752121
# 29   5.226543   2.884578   5.713686
# ..        ...        ...        ...
# 70  -4.767842  -3.940154  -5.067821
# 71  -4.473922  -4.007741  -4.685694
# 72  -4.128147  -4.573282  -5.429174
# 73  -4.252484  -6.072905  -4.236229
# 74  -4.670711  -3.734625  -4.768426
# 75  -3.800211  -5.369609  -3.856928
# 76  -5.690120  -4.483382  -5.384021
# 77  -3.487496  -6.423580  -6.023536
# 78  -4.884941  -5.324660  -8.100634
# 79  -4.739367  -4.408476  -4.158033
# 80  -5.245336  -6.135647  -2.523126
# 81  -4.995252  -4.414891  -5.455427
# 82  -4.004398  -5.005018  -4.367004
# 83  -5.373808  -5.218304  -5.528865
# 84  -5.132340  -5.253524  -3.618572
# 85  -6.277164  -3.550866  -6.502846
# 86  -5.292355  -4.898170  -3.979033
# 87  -5.264926  -4.891724  -6.720817
# 88  -3.994986  -4.879813  -3.702274
# 89  -4.849999  -4.864293  -4.223450
# 90  -6.197619  -6.119640  -3.425356
# 91  -4.507994  -4.629468  -4.237646
# 92  -6.447036  -5.634221  -5.811700
# 93  -5.137179  -5.604236  -5.163727
# 94  -3.174107  -5.153928  -2.511107
# 95  -5.698920  -3.570920  -6.557092
# 96  -2.937957  -4.459990  -4.532771
# 97  -3.769452  -6.227069  -5.136485
# 98  -3.499007  -4.356902  -6.604562
# 99  -5.630381  -4.993928  -4.763588
#
# [200 rows x 3 columns]

# %% [markdown]
# There is an issue here? What is it?

# %%
pd.set_option("max.rows", None)
data1
# Out:
#      index  feature_1  feature_2  feature_3
# 0        0   4.550507   5.004117   5.210501
# 1        1   5.214715   5.721761   6.735769
# 2        2   4.824738   4.032436   4.419802
# 3        3   4.018777   2.726202   2.457787
# 4        4   3.876723   4.054230   6.267056
# 5        5   4.839432   5.513151   4.915874
# 6        6   4.621005   4.312721   5.390580
# 7        7   5.029286   5.236494   3.800252
# 8        8   5.473726   5.434129   6.984428
# 9        9   5.000643   4.985643   4.702337
# 10      10   6.104494   4.898955   4.509896
# 11      11   3.821223   4.918051   3.977788
# 12      12   4.586813   4.444995   6.229879
# 13      13   5.229213   6.982055   5.359106
# 14      14   5.427002   4.917086   6.227721
# 15      15   5.454848   3.331649   4.293668
# 16      16   4.712216   5.670613   5.476897
# 17      17   4.325281   4.913907   5.649319
# 18      18   4.888530   5.417880   6.992144
# 19      19   2.432764   4.836896   5.292530
# 20      20   6.304912   6.358224   6.171997
# 21      21   4.550257   5.830858   2.754417
# 22      22   6.356579   6.939571   4.600550
# 23      23   8.001308   7.220978   3.111329
# 24      24   4.871987   5.208729   5.512565
# 25      25   4.734293   3.335230   5.279084
# 26      26   4.400667   6.239742   4.844260
# 27      27   3.919119   4.814754   5.610985
# 28      28   3.559219   5.075045   6.752121
# 29      29   5.226543   2.884578   5.713686
# 30      30   5.413053   3.967094   2.739271
# 31      31   6.963712   6.858773   4.275892
# 32      32   3.908594   4.071826   6.219562
# 33      33   2.807534   4.374906   4.822233
# 34      34   4.127969   4.884010   6.190002
# 35      35   3.920639   6.038514   5.710110
# 36      36   3.645248   1.526010   4.981410
# 37      37   5.125129   5.453532   4.843263
# 38      38   6.411610   4.751413   4.528197
# 39      39   5.167007   4.959955   5.084454
# 40      40   4.947054   4.404597   7.440984
# 41      41   5.124994   5.407552   6.179417
# 42      42   5.351559   6.141382   5.081212
# 43      43   3.848583   6.268129   4.825829
# 44      44   4.601880   4.077625   5.875156
# 45      45   4.813841   4.084722   5.250620
# 46      46   3.667238   5.427155   2.901372
# 47      47   5.116256   4.931682   5.655005
# 48      48   4.118109   4.947758   4.656156
# 49      49   4.896611   4.744276   6.430912
# 50      50   5.923401   4.108235   4.115861
# 51      51   4.553802   3.860917   5.155595
# 52      52   5.693751   5.554030   4.987709
# 53      53   4.459439   5.614398   4.604481
# 54      54   5.778749   5.551569   4.862977
# 55      55   6.570885   4.059379   4.238491
# 56      56   4.669163   4.236932   4.495911
# 57      57   5.667728   5.098136   4.647383
# 58      58   5.664494   4.166437   1.806575
# 59      59   6.056256   4.656848   4.860657
# 60      60   5.746172   3.594036   6.981890
# 61      61   6.364902   5.355215   2.434252
# 62      62   4.319384   4.438766   3.701200
# 63      63   5.268425   3.539366   4.717525
# 64      64   5.222914   5.975715   5.047936
# 65      65   4.853370   5.052524   4.866973
# 66      66   5.338295   4.242981   5.472921
# 67      67   6.243258   4.908468   4.686805
# 68      68   4.681574   4.938464   4.130720
# 69      69   4.963086   3.700579   4.984304
# 70      70   5.387284   8.225710   6.196701
# 71      71   3.586429   3.813081   5.214290
# 72      72   3.872317   6.590932   5.669937
# 73      73   4.192027   3.840367   5.708830
# 74      74   5.357935   3.006816   5.653635
# 75      75   5.771992   3.967685   5.012368
# 76      76   3.541832   4.837343   5.058259
# 77      77   2.952866   4.397818   6.446209
# 78      78   4.526261   7.771858   5.323410
# 79      79   6.628729   6.424760   4.589765
# 80      80   5.676814   5.595515   3.900539
# 81      81   6.084391   6.390533   6.439919
# 82      82   6.489887   5.545105   5.308301
# 83      83   5.652815   5.947099   4.467796
# 84      84   4.293793   4.500529   5.913410
# 85      85   5.398922   4.921744   4.597460
# 86      86   5.506660   5.420716   6.562177
# 87      87   4.181096   4.894894   6.640280
# 88      88   5.054561   4.041339   4.762458
# 89      89   5.874695   5.425615   6.654826
# 90      90   6.248646   3.834454   3.797875
# 91      91   4.726300   6.046219   3.767911
# 92      92   3.167824   4.741116   4.854370
# 93      93   5.449209   6.039298   4.760448
# 94      94   6.097078   4.797226   6.308433
# 95      95   4.109412   4.007250   6.640893
# 96      96   3.732948   5.057746   3.607842
# 97      97   4.698066   4.756439   4.265537
# 98      98   7.094876   4.582392   5.921396
# 99      99   6.113593   4.105761   5.335692
# 100      0  -4.763054  -6.406415  -7.118273
# 101      1  -5.995944  -4.872129  -3.334770
# 102      2  -4.673589  -6.013035  -4.856640
# 103      3  -5.242724  -4.759708  -4.689278
# 104      4  -2.567967  -4.729315  -5.523268
# 105      5  -3.702838  -4.675154  -7.636744
# 106      6  -5.243084  -4.453957  -5.537260
# 107      7  -6.479020  -5.134231  -6.181736
# 108      8  -4.691458  -5.723266  -6.691257
# 109      9  -6.139086  -3.633822  -4.459974
# 110     10  -5.300757  -6.662043  -4.777763
# 111     11  -6.227218  -3.235111  -4.336425
# 112     12  -5.494561  -4.657927  -6.818675
# 113     13  -6.682880  -6.498982  -4.962542
# 114     14  -6.839839  -4.378925  -6.577332
# 115     15  -4.769352  -5.725447  -4.710624
# 116     16  -4.044394  -4.623992  -4.831944
# 117     17  -4.445691  -6.231703  -2.218700
# 118     18  -5.859432  -5.807795  -7.107271
# 119     19  -5.595377  -4.626127  -4.193703
# 120     20  -6.729128  -5.050338  -5.961250
# 121     21  -5.109302  -5.302860  -5.334609
# 122     22  -7.551426  -5.072018  -6.344336
# 123     23  -5.315927  -4.819517  -3.891787
# 124     24  -4.484113  -5.812021  -5.093606
# 125     25  -3.967590  -6.058978  -5.688826
# 126     26  -4.631650  -7.303967  -5.996411
# 127     27  -4.659192  -4.490026  -5.001787
# 128     28  -5.136802  -3.773384  -3.459054
# 129     29  -7.554741  -4.887211  -5.773457
# 130     30  -5.695740  -5.513158  -4.935129
# 131     31  -5.762412  -3.630515  -3.673532
# 132     32  -3.651749  -5.330002  -5.132426
# 133     33  -4.109197  -4.792505  -5.513924
# 134     34  -4.911213  -6.723590  -5.644920
# 135     35  -4.799401  -5.102692  -5.681053
# 136     36  -2.195818  -5.024614  -4.671293
# 137     37  -4.699151  -6.268181  -5.270511
# 138     38  -5.233910  -4.207572  -2.158949
# 139     39  -3.866211  -3.545747  -5.493837
# 140     40  -3.645416  -4.770994  -4.633909
# 141     41  -5.192163  -3.142083  -3.795953
# 142     42  -4.329092  -5.310079  -5.291454
# 143     43  -5.283165  -2.992333  -5.130949
# 144     44  -3.218675  -3.623706  -5.262160
# 145     45  -4.246086  -5.216454  -6.012811
# 146     46  -5.193713  -4.793289  -6.729692
# 147     47  -2.727720  -4.813922  -5.739461
# 148     48  -5.755904  -3.975565  -5.820117
# 149     49  -4.616013  -6.095573  -5.105419
# 150     50  -5.676692  -4.585939  -4.840162
# 151     51  -4.228579  -5.833584  -4.119721
# 152     52  -4.673663  -3.834831  -5.155362
# 153     53  -5.745103  -4.537230  -6.210013
# 154     54  -5.829056  -4.174003  -5.524744
# 155     55  -5.556765  -4.627389  -2.917809
# 156     56  -4.126937  -4.445850  -3.845111
# 157     57  -6.005259  -5.433857  -6.303265
# 158     58  -4.693357  -3.366533  -3.665340
# 159     59  -5.531950  -5.551048  -3.982422
# 160     60  -4.813882  -6.362611  -5.697688
# 161     61  -5.716807  -3.793032  -5.211649
# 162     62  -6.495788  -3.225056  -2.661708
# 163     63  -6.485427  -5.010748  -3.986682
# 164     64  -5.323378  -5.985462  -4.017127
# 165     65  -5.834366  -4.601515  -4.812258
# 166     66  -5.721563  -5.228018  -3.870773
# 167     67  -4.805866  -4.402863  -5.607024
# 168     68  -5.495523  -4.626484  -5.131404
# 169     69  -6.598877  -5.737787  -4.782313
# 170     70  -4.767842  -3.940154  -5.067821
# 171     71  -4.473922  -4.007741  -4.685694
# 172     72  -4.128147  -4.573282  -5.429174
# 173     73  -4.252484  -6.072905  -4.236229
# 174     74  -4.670711  -3.734625  -4.768426
# 175     75  -3.800211  -5.369609  -3.856928
# 176     76  -5.690120  -4.483382  -5.384021
# 177     77  -3.487496  -6.423580  -6.023536
# 178     78  -4.884941  -5.324660  -8.100634
# 179     79  -4.739367  -4.408476  -4.158033
# 180     80  -5.245336  -6.135647  -2.523126
# 181     81  -4.995252  -4.414891  -5.455427
# 182     82  -4.004398  -5.005018  -4.367004
# 183     83  -5.373808  -5.218304  -5.528865
# 184     84  -5.132340  -5.253524  -3.618572
# 185     85  -6.277164  -3.550866  -6.502846
# 186     86  -5.292355  -4.898170  -3.979033
# 187     87  -5.264926  -4.891724  -6.720817
# 188     88  -3.994986  -4.879813  -3.702274
# 189     89  -4.849999  -4.864293  -4.223450
# 190     90  -6.197619  -6.119640  -3.425356
# 191     91  -4.507994  -4.629468  -4.237646
# 192     92  -6.447036  -5.634221  -5.811700
# 193     93  -5.137179  -5.604236  -5.163727
# 194     94  -3.174107  -5.153928  -2.511107
# 195     95  -5.698920  -3.570920  -6.557092
# 196     96  -2.937957  -4.459990  -4.532771
# 197     97  -3.769452  -6.227069  -5.136485
# 198     98  -3.499007  -4.356902  -6.604562
# 199     99  -5.630381  -4.993928  -4.763588

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-14c805a83dba> in <module>()
# ----> 1 df2.columns = col2
#       2 df3(3)
#
# NameError: name 'col2' is not defined

# %% [markdown]
# We have duplicate index values!

# %%
#We can reset the index
data1.reset_index(inplace=True)

# %% [markdown]
# Concatenate dataframes along axis 1 aka attach dataframes side by side.

# %%
#Change column names of df2 so we avoid duplication issue
col2 = ["feature_4", "feature_5", "feature_6"]
df2.head()
# Out:
#    feature_4  feature_5  feature_6
# 0  -4.763054  -6.406415  -7.118273
# 1  -5.995944  -4.872129  -3.334770
# 2  -4.673589  -6.013035  -4.856640
# 3  -5.242724  -4.759708  -4.689278
# 4  -2.567967  -4.729315  -5.523268

# %%
#Make list of dataframes
dflist = [df1, df2]

#Concatenate dataframes but this time set axis = 1
data2 = pd.concat(dflist, axis=1)

#View concatenated dataframe which 100 rows by 4 columns

data2
# Out:
#     feature_1  feature_2  feature_3  feature_4  feature_5  feature_6
# 0    4.550507   5.004117   5.210501  -4.763054  -6.406415  -7.118273
# 1    5.214715   5.721761   6.735769  -5.995944  -4.872129  -3.334770
# 2    4.824738   4.032436   4.419802  -4.673589  -6.013035  -4.856640
# 3    4.018777   2.726202   2.457787  -5.242724  -4.759708  -4.689278
# 4    3.876723   4.054230   6.267056  -2.567967  -4.729315  -5.523268
# 5    4.839432   5.513151   4.915874  -3.702838  -4.675154  -7.636744
# 6    4.621005   4.312721   5.390580  -5.243084  -4.453957  -5.537260
# 7    5.029286   5.236494   3.800252  -6.479020  -5.134231  -6.181736
# 8    5.473726   5.434129   6.984428  -4.691458  -5.723266  -6.691257
# 9    5.000643   4.985643   4.702337  -6.139086  -3.633822  -4.459974
# 10   6.104494   4.898955   4.509896  -5.300757  -6.662043  -4.777763
# 11   3.821223   4.918051   3.977788  -6.227218  -3.235111  -4.336425
# 12   4.586813   4.444995   6.229879  -5.494561  -4.657927  -6.818675
# 13   5.229213   6.982055   5.359106  -6.682880  -6.498982  -4.962542
# 14   5.427002   4.917086   6.227721  -6.839839  -4.378925  -6.577332
# 15   5.454848   3.331649   4.293668  -4.769352  -5.725447  -4.710624
# 16   4.712216   5.670613   5.476897  -4.044394  -4.623992  -4.831944
# 17   4.325281   4.913907   5.649319  -4.445691  -6.231703  -2.218700
# 18   4.888530   5.417880   6.992144  -5.859432  -5.807795  -7.107271
# 19   2.432764   4.836896   5.292530  -5.595377  -4.626127  -4.193703
# 20   6.304912   6.358224   6.171997  -6.729128  -5.050338  -5.961250
# 21   4.550257   5.830858   2.754417  -5.109302  -5.302860  -5.334609
# 22   6.356579   6.939571   4.600550  -7.551426  -5.072018  -6.344336
# 23   8.001308   7.220978   3.111329  -5.315927  -4.819517  -3.891787
# 24   4.871987   5.208729   5.512565  -4.484113  -5.812021  -5.093606
# 25   4.734293   3.335230   5.279084  -3.967590  -6.058978  -5.688826
# 26   4.400667   6.239742   4.844260  -4.631650  -7.303967  -5.996411
# 27   3.919119   4.814754   5.610985  -4.659192  -4.490026  -5.001787
# 28   3.559219   5.075045   6.752121  -5.136802  -3.773384  -3.459054
# 29   5.226543   2.884578   5.713686  -7.554741  -4.887211  -5.773457
# 30   5.413053   3.967094   2.739271  -5.695740  -5.513158  -4.935129
# 31   6.963712   6.858773   4.275892  -5.762412  -3.630515  -3.673532
# 32   3.908594   4.071826   6.219562  -3.651749  -5.330002  -5.132426
# 33   2.807534   4.374906   4.822233  -4.109197  -4.792505  -5.513924
# 34   4.127969   4.884010   6.190002  -4.911213  -6.723590  -5.644920
# 35   3.920639   6.038514   5.710110  -4.799401  -5.102692  -5.681053
# 36   3.645248   1.526010   4.981410  -2.195818  -5.024614  -4.671293
# 37   5.125129   5.453532   4.843263  -4.699151  -6.268181  -5.270511
# 38   6.411610   4.751413   4.528197  -5.233910  -4.207572  -2.158949
# 39   5.167007   4.959955   5.084454  -3.866211  -3.545747  -5.493837
# 40   4.947054   4.404597   7.440984  -3.645416  -4.770994  -4.633909
# 41   5.124994   5.407552   6.179417  -5.192163  -3.142083  -3.795953
# 42   5.351559   6.141382   5.081212  -4.329092  -5.310079  -5.291454
# 43   3.848583   6.268129   4.825829  -5.283165  -2.992333  -5.130949
# 44   4.601880   4.077625   5.875156  -3.218675  -3.623706  -5.262160
# 45   4.813841   4.084722   5.250620  -4.246086  -5.216454  -6.012811
# 46   3.667238   5.427155   2.901372  -5.193713  -4.793289  -6.729692
# 47   5.116256   4.931682   5.655005  -2.727720  -4.813922  -5.739461
# 48   4.118109   4.947758   4.656156  -5.755904  -3.975565  -5.820117
# 49   4.896611   4.744276   6.430912  -4.616013  -6.095573  -5.105419
# 50   5.923401   4.108235   4.115861  -5.676692  -4.585939  -4.840162
# 51   4.553802   3.860917   5.155595  -4.228579  -5.833584  -4.119721
# 52   5.693751   5.554030   4.987709  -4.673663  -3.834831  -5.155362
# 53   4.459439   5.614398   4.604481  -5.745103  -4.537230  -6.210013
# 54   5.778749   5.551569   4.862977  -5.829056  -4.174003  -5.524744
# 55   6.570885   4.059379   4.238491  -5.556765  -4.627389  -2.917809
# 56   4.669163   4.236932   4.495911  -4.126937  -4.445850  -3.845111
# 57   5.667728   5.098136   4.647383  -6.005259  -5.433857  -6.303265
# 58   5.664494   4.166437   1.806575  -4.693357  -3.366533  -3.665340
# 59   6.056256   4.656848   4.860657  -5.531950  -5.551048  -3.982422
# 60   5.746172   3.594036   6.981890  -4.813882  -6.362611  -5.697688
# 61   6.364902   5.355215   2.434252  -5.716807  -3.793032  -5.211649
# 62   4.319384   4.438766   3.701200  -6.495788  -3.225056  -2.661708
# 63   5.268425   3.539366   4.717525  -6.485427  -5.010748  -3.986682
# 64   5.222914   5.975715   5.047936  -5.323378  -5.985462  -4.017127
# 65   4.853370   5.052524   4.866973  -5.834366  -4.601515  -4.812258
# 66   5.338295   4.242981   5.472921  -5.721563  -5.228018  -3.870773
# 67   6.243258   4.908468   4.686805  -4.805866  -4.402863  -5.607024
# 68   4.681574   4.938464   4.130720  -5.495523  -4.626484  -5.131404
# 69   4.963086   3.700579   4.984304  -6.598877  -5.737787  -4.782313
# 70   5.387284   8.225710   6.196701  -4.767842  -3.940154  -5.067821
# 71   3.586429   3.813081   5.214290  -4.473922  -4.007741  -4.685694
# 72   3.872317   6.590932   5.669937  -4.128147  -4.573282  -5.429174
# 73   4.192027   3.840367   5.708830  -4.252484  -6.072905  -4.236229
# 74   5.357935   3.006816   5.653635  -4.670711  -3.734625  -4.768426
# 75   5.771992   3.967685   5.012368  -3.800211  -5.369609  -3.856928
# 76   3.541832   4.837343   5.058259  -5.690120  -4.483382  -5.384021
# 77   2.952866   4.397818   6.446209  -3.487496  -6.423580  -6.023536
# 78   4.526261   7.771858   5.323410  -4.884941  -5.324660  -8.100634
# 79   6.628729   6.424760   4.589765  -4.739367  -4.408476  -4.158033
# 80   5.676814   5.595515   3.900539  -5.245336  -6.135647  -2.523126
# 81   6.084391   6.390533   6.439919  -4.995252  -4.414891  -5.455427
# 82   6.489887   5.545105   5.308301  -4.004398  -5.005018  -4.367004
# 83   5.652815   5.947099   4.467796  -5.373808  -5.218304  -5.528865
# 84   4.293793   4.500529   5.913410  -5.132340  -5.253524  -3.618572
# 85   5.398922   4.921744   4.597460  -6.277164  -3.550866  -6.502846
# 86   5.506660   5.420716   6.562177  -5.292355  -4.898170  -3.979033
# 87   4.181096   4.894894   6.640280  -5.264926  -4.891724  -6.720817
# 88   5.054561   4.041339   4.762458  -3.994986  -4.879813  -3.702274
# 89   5.874695   5.425615   6.654826  -4.849999  -4.864293  -4.223450
# 90   6.248646   3.834454   3.797875  -6.197619  -6.119640  -3.425356
# 91   4.726300   6.046219   3.767911  -4.507994  -4.629468  -4.237646
# 92   3.167824   4.741116   4.854370  -6.447036  -5.634221  -5.811700
# 93   5.449209   6.039298   4.760448  -5.137179  -5.604236  -5.163727
# 94   6.097078   4.797226   6.308433  -3.174107  -5.153928  -2.511107
# 95   4.109412   4.007250   6.640893  -5.698920  -3.570920  -6.557092
# 96   3.732948   5.057746   3.607842  -2.937957  -4.459990  -4.532771
# 97   4.698066   4.756439   4.265537  -3.769452  -6.227069  -5.136485
# 98   7.094876   4.582392   5.921396  -3.499007  -4.356902  -6.604562
# 99   6.113593   4.105761   5.335692  -5.630381  -4.993928  -4.763588

# %% [markdown]
# ### Merging Dataframes
#
# Similar to SQL joins, we'll combine two DataFrames using a unique ID found in both DataFrames.

# %%
#Create sample dataframes
A = pd.DataFrame({'color': ['green', 'yellow', 'red'], 'num':[1, 2, 3]})
A
# Out:
#     color  num
# 0   green    1
# 1  yellow    2
# 2     red    3

# %%
B = pd.DataFrame({'color': ['green', 'yellow', 'pink'], 'size':['S', 'M', 'L']})
B
# Out:
#     color size
# 0   green    S
# 1  yellow    M
# 2    pink    L

# %% [markdown]
# Inner join: Only include observations found in both A and B:

# %%
#Use pd.merge to do join. Set how = "inner"
pd.merge(A, B, how = "inner")
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M

# %%
#Setting on = "color" does same thing
pd.merge(A, B, how='inner', on="color")
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M

# %% [markdown]
# If you don't set column to do the join on, then pandas will use the shared column. In this example, the shared column is "color".

# %% [markdown]
# Outer join: Include observations found in either A or B:

# %%
#Set how = "outer"
pd.merge(A, B, how = "outer", on = "color")
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2     red  3.0  NaN
# 3    pink  NaN    L

# %% [markdown]
# Left join: Include all observations found in A:

# %%
#Set how = "left"
pd.merge(A, B, how = "left")
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M
# 2     red    3  NaN

# %% [markdown]
# Right join: Include all observations found in B:

# %%
pd.merge(A, B, how = "right")
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2    pink  NaN    L

# %% [markdown]
# Another example

# %%
#Make dataframes from dictionaries
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}


data1 = pd.DataFrame(raw_data_1, columns = ['subject_id', 'first_name', 'last_name'])
data2 = pd.DataFrame(raw_data_2, columns = ['subject_id', 'first_name', 'last_name'])
data3 = pd.DataFrame(raw_data_3, columns = ['subject_id','test_id'])

data3
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %%
#Concatenate data1 and data2 on axis 0 assign it to all_data
list_of_data = [data1, data2]
all_data = pd.concat(list_of_data)
all_data.head()
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches

# %%
#Inner join all_data and data on the subject_id column
pd.merge(all_data, data3, how = "inner")
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15

# %% [markdown]
# ### Exercise time
#
# 1. Merge only the data that has the same 'subject_id' on both data1 and data2
#
# 2. Merge all values in data1 and data2, with matching records from both sides where available.

# %%
#Answer 1 
pd.merge(data1, data2, on = "subject_id", how= "inner")
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %%
#Answer 2
pd.merge(data1, data2, on = "subject_id", how= "outer")
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
# 5          6          NaN         NaN         Bran     Balwner
# 6          7          NaN         NaN        Bryce       Brice
# 7          8          NaN         NaN        Betty      Btisan

# %% [markdown]
# ### More resources concatenating, merging, and other ways to transforms data in pandas.
#
# http://www.datacarpentry.org/python-ecology-lesson/04-merging-data/
# https://github.com/shanealynn/Pandas-Merge-Tutorial/blob/master/Pandas%20Merge%20Tutorial.ipynb
# https://www.shanelynn.ie/merge-join-dataframes-python-pandas-index-1/
# https://pythonprogramming.net/concatenate-append-data-analysis-python-pandas-tutorial/
# https://www.dezyre.com/data-science-in-python-tutorial/pandas-introductory-tutorial-part-3
#
# Pivot tables: http://pbpython.com/pandas-pivot-table-explained.html

# %% [markdown]
# This brings us to the end of the pandas section. We'll learn some pandas things but this is the last time pandas is the last lesson. There's a lot more to learn so I encourage to take advantage of the resources I gave you.

# %% [markdown]
# ## Plotting

# %%
#import plotting library
import matplotlib.pyplot as plt
#Don't forget this part!
# %matplotlib inline

# %%
#Make some random numpy arays

a = np.random.rand(100)
b = np.random.rand(100)*3 + 2

# %% [markdown]
# Line plots

# %%
#Use .plot() to make a line plot with a
plt.plot(a)
plt.show()

# %%
#Change color to green
plt.plot(a, c = "g")
plt.show()

# %%
#Change thickness of the line
plt.plot(a, c = "c", linewidth = .3)
plt.show()

# %%
#Change opaqueness of plot. Scale is 0.0-1.0. Keyword is alpha
#1.0 is opaque
#0.0 is transparent
plt.plot(a, c = "k", alpha = .6);

# %% [markdown]
# 1. Adjust size of plot
# 2. Add some context to the plot

# %%
#Set plot size to 8x6 
plt.figure(figsize = (8, 6))

#Call plot with linewidth to 3
plt.plot(a, linewidth = 3)

#Label the x-axis
plt.xlabel("This is the x axis")

#Label the y-axis
plt.ylabel("This is the y axis")

#Give the plot a title
plt.title("Our Fantastic Plot")

plt.show()

# %% [markdown]
# We can combine charts together on a single plot

# %%
#Make line plots of a and b and give them separate colors
plt.plot(a, c = "c")
plt.plot(b, c = "y");

# %% [markdown]
# We can display this using subplots

# %%
#Setting size
plt.figure(figsize=(12,4))

#Subplot #1
plt.subplot(1, 2, 1)
plt.plot(a, color='purple')
plt.ylabel('Values')
plt.title('Random Plot 1')

#Subplot #2
plt.subplot(1, 2, 2)
plt.plot(b, color='green')
plt.ylabel('Values')
plt.title('Random Plot 2')

#tight_layout() adds spacing between plots
plt.tight_layout()
plt.show()

# %% [markdown]
# Scatter plots

# %%
#Plot a vs b using a scatter plot
#Adjust size
plt.figure(figsize = (8,6))

#Call .scatter() method. Set s= 30 to increase size of plot.
plt.scatter(a, b, s = 30)

#Label x and y axes
plt.xlabel("A array")
plt.ylabel("B array")
plt.show()

# %%
#Lets call same plot but let's impose some limits on it

plt.figure(figsize=(8, 5))

#Call .scatter() method. Set s= 30 to increase size of plot.
plt.scatter(a, b, s=30)

#Label x and y axes
plt.xlabel("A array")
plt.ylabel("B array")

#Limits on both axes
plt.xlim(0.4, 0.8)
plt.ylim(3, 4)

plt.show()

# %% [markdown]
# Change the size and color of individual dots

# %%
#Create numpy array of sizes
sizes = np.random.random(100)*200

#Create numpy array of colors randomly selected from color_list a 100 times
color_list = ["r", "g", "y", "b"]
colors = np.random.choice(color_list, size=100)

# %%
sizes[:20]
# Out:
# array([  49.91567764,   34.12380332,  117.93922579,   39.9775774 ,
#           4.67241011,  158.8799758 ,  152.20012822,   92.39180932,
#          23.22962706,   83.22242097,   95.59692495,  119.20587158,
#         123.89655473,  132.32660842,  181.95935019,  126.70552635,
#         100.90988079,   71.20940147,  125.69241656,   16.95643898])

# %%
colors[:20]
# Out:
# array(['b', 'b', 'r', 'r', 'b', 'y', 'b', 'y', 'r', 'g', 'y', 'b', 'r',
#        'r', 'r', 'g', 'r', 'g', 'g', 'y'],
#       dtype='|S1')

# %% [markdown]
# Pass sizes and colors in to scatter plot function

# %%
#Set size to 8x5
plt.figure(figsize = (8,5))

#Set s to sizes and c to colors
plt.scatter(a, b, s = sizes, c = colors)

plt.xlabel("A array")
plt.ylabel("B array")
plt.show()

# %% [markdown]
# Voila! We have a colorful scatter plot of with dots of varying sizes
#
# However let's try making it look a little nicer.

# %%
#Load in the fivethirtyeight plot style
plt.style.use("fivethirtyeight")

# %%
#Let's run our scatter plot again
plt.figure(figsize=(8, 5))
plt.scatter(a, b, s=sizes, c=colors)
plt.xlabel("A array")
plt.ylabel("B array")
plt.show()

# %% [markdown]
# Much better isn't it?

# %%
#Available styles at out disposable

# %%
plt.style.available
# Out:
# [u'seaborn-darkgrid',
#  u'seaborn-notebook',
#  u'classic',
#  u'seaborn-ticks',
#  u'grayscale',
#  u'bmh',
#  u'seaborn-talk',
#  u'dark_background',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'_classic_test',
#  u'seaborn-colorblind',
#  u'seaborn-deep',
#  u'seaborn-whitegrid',
#  u'seaborn-bright',
#  u'seaborn-poster',
#  u'seaborn-muted',
#  u'seaborn-paper',
#  u'seaborn-white',
#  u'seaborn-pastel',
#  u'seaborn-dark',
#  u'seaborn',
#  u'seaborn-dark-palette']

# %% [markdown]
# Bar plots

# %%
#Lists of seasons and average high temperature for San Francisco
seasons = ["Spring", "Summer", "Fall", "Winter"]
sf_temps = [64, 68, 63, 59]

# %%
#Plot bar plot of temperatures on y axis and season on x axis

#Requires a list of integers to be used as position coordinates.
#Set pos equal to array-range of the length of seasons
pos = np.arange(len(seasons))

#Set bar width to 0.4
w = 0.4

# %%
#Let's fill in the blank together
plt.bar(left = pos, width = w, height= sf_temps, tick_label = seasons, align = "center")
plt.show()

# %% [markdown]
# Same chart but with horizontal orientation. But be careful!

# %%
#Bottom = pos
#Width = sf_temps
#Height = w
#tick_labels = seasons
#align = "center"

plt.barh(bottom = pos, width = sf_temps, height = w, tick_label = seasons, align="center")
plt.show()

# %% [markdown]
# Compare San Francisco to Los Angeles and New York

# %%
#List of temperatures for LA and NY
la_temps = [73, 87, 74, 62]
ny_temps = [58, 85, 53, 39]

# %%
#Plot all three cities together on same plot

w = 0.2
#Bar plot number 1: San Francisco

#Shift positioning to the left by width value
plt.bar(pos-w, width=w, height=sf_temps, align="center")

#Bar plot number 2: Los Angeles
#Keep pos the same
#The middle chart gets the tick_label
#We only need to call it once because they all have the same labels
plt.bar(pos, width=w, height=la_temps, color="r", tick_label=seasons, align = "center")

#Bar plot number 3: New York
#Shift positioning to the right by width value
plt.bar(pos + w, width=w, height=ny_temps, color = "g", align = "center")

plt.ylabel("Average Temperatures")
#Set a legend. bbox_to_anchor moves legend out of the way
plt.legend(["San Francisco", "Los Angeles", "New York"],
          fontsize="small",
          bbox_to_anchor=(1.4, .95))
plt.show()

# %% [markdown]
# ### Statistical plots

# %% [markdown]
# Histograms

# %%
#Create numpy array with a normal distribution of 3000 values, mean 10, and std of 3
a = np.random.normal(loc=10,size=3000, scale=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7c4d7da4ffdd> in <module>()
#       1 #Create numpy array with a normal distribution of 3000 values, mean 10, and std of 3
# ----> 2 a = np.random.normal(loc=10,size=3000, scale=3)
#
# NameError: name 'np' is not defined

# %%
#Make a histogram of a
plt.hist(a);

# %% [markdown]
# Shows data actually is a normal distribution

# %% [markdown]
# Let's make some changes

# %%
#Set bins = 20 and normed=True
plt.hist(a, bins =100, normed = True);

# %% [markdown]
# What is the difference?

# %%
more bars..

# %% [markdown]
# Lets show two histograms on the same plot

# %%
#Create another numpy array but this time with a gamma distribution

b = np.random.normal(loc=5,size=3000, scale=1)
#Call hist on a and b. Uses bins =50 for both.
#Use different colors for both plots
plt.figure(figsize=(9, 8))
plt.hist(a, bins = 50, color = "r", alpha = .5)
plt.hist(b, bins = 50, alpha = .5);

# %% [markdown]
# Compare and contrast the two plots

# %% [markdown]
# #### Boxplots

# %%
#Set random seed so we all generate the same random data data
np.random.seed(42)
x = np.random.normal(10, 5, 1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6d701bc7f892> in <module>()
#       1 #Set random seed so we all generate the same random data data
# ----> 2 np.random.seed(42)
#       3 x = np.random.normal(10, 5, 1000)
#
# NameError: name 'np' is not defined

# %% [markdown]
# Who knows what random seed does ?

# %%
x[:10]
# Out:
# array([ 12.48357077,   9.30867849,  13.23844269,  17.61514928,
#          8.82923313,   8.82931522,  17.89606408,  13.83717365,
#          7.65262807,  12.71280022])

# %%
x = np.random.normal(10, 5, 1000)
# Generate box plot.
plt.plot(x, kind="box")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2382025b8aa1> in <module>()
# ----> 1 x = np.random.normal(10, 5, 1000)
#       2 # Generate box plot.
#       3 plt.plot(x, kind="box")
#
# NameError: name 'np' is not defined

# %% [markdown]
# - The box in the boxplot represents the middle 50% of values, all the values between the 25th and 75th percentile. Aka the interquartile range "IQR". The red line represents the median.
#
# - The whiskers will extend up and down up to a distance of 1.5x the IQR away from the top and bottom of the box. If all values are within that range, the whiskers will go to the max and min of the variable.

# %% [markdown]
# <b> Which do you think is better for showing the distribution of a set of numbers? Boxplot or histogram? Why?<b>

# %% [markdown]
# ### Plotting with Pandas
# <br>
# We can create charts directly from pandas dataframes and series. Let's find out how to do so with pokemon data!
#
# Data source:https://www.kaggle.com/abcsds/pokemon

# %%
#Data path
path  = "../data/Pokemon.csv"

#Load pokemon data into a pandas dataframe
pm = pd.read_csv(path)

# %%
pm.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#Clean up the columns by lowercasing them and getting rid spaces and periods
pm.columns = pm.columns.str.lower().str.replace(" ", "_").str.replace(".", "")
pm.head()
# Out:
#    #                   name type_1  type_2  total  hp  attack  defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    sp_atk  sp_def  speed  generation  legendary
# 0      65      65     45           1      False
# 1      80      80     60           1      False
# 2     100     100     80           1      False
# 3     122     120     80           1      False
# 4      60      50     65           1      False

# %%
#Drop the hashtag column from data
pm.drop("#", axis = 1, inplace = True)

# %% [markdown]
# Use can matplotlib on pandas data

# %%
plt.hist(pm.total)
plt.show()

# %% [markdown]
# But we're going to use the built-in plotting functionality of pandas.

# %%
#Same graph as above but using pandas
pm.total.plot(kind="hist")

# %% [markdown]
# Make a histogram of all the numerical columns in the data

# %%
#Call .hist() on pm and drop 
pm.hist(figsize=(12,9))
plt.tight_layout()
plt.show()

# %% [markdown]
# Pandas bar plots

# %%
#Assign pm.type_1 to poke_type
poke_type = pm.type_1

# %% [markdown]
# Use a bar plot to visualize the counts of the various types of pokemon.

# %%
#Use value_counts to get the tallies of the types and assign to type_vc

type_vc = poke_type.value_counts()

#Call .plot on type_vc and set kind = "bar"

type_vc.plot(kind="bar", rot = 55)
plt.tight_layout()
plt.show()

# %% [markdown]
# Let's try this again but with some adjustments

# %%
#Set kind = "barh" to make it a horizontal plot
#Set figsize= (8, 5) to adjust size
#Set color = "g"
#Set alpha = 0.6
#Set width = 1
type_vc.plot(kind="barh", figsize=(8,5), color="g", width = 1);

# %% [markdown]
# Pandas scatter plots

# %%
#View data
pm.head()

# %% [markdown]
# Let's visualize attack vs defense

# %%
#Specify column names for the x and y axes
#Set kind = "scatter"
pm.plot(kind="scatter", x = "defense", y = "attack");

# %% [markdown]
# What is the relationship between the two attributes?

# %% [markdown]
# Let's colorify the plot!

# %%
#Same code as before but this time specify legendary as the color
pm.plot(x = "defense", y = "attack", kind = "scatter", c = pm.legendary, figsize=( 8, 6))
plt.show()

# %% [markdown]
# What is the difference between legendary and non-legendary pokemon when it comes to attack and defense?

# %% [markdown]
# Specify our own color scheme

# %%
#Create color dictionary, which we'll use to map over the pandas series. 
#Convert False to yellow and True to green
color_dict = {False: "y", True:"g"}

#Create new pandas series object which is the legendary column but with color-encoding
colors = pm.legendary.map(color_dict)

# %%
#Scatter with new color encoding
pm.plot(x = "defense", y = "attack", kind = "scatter", alpha=.4, c = colors, figsize=(10, 7))
plt.show()

# %% [markdown]
# Let's try a similar plot but this time we'll use point size to visualize the speed of the pokemon

# %%
#Set s = pm.speed
pm.plot(x="defense", y = "attack", kind="scatter",alpha=.4, s = pm.speed, figsize=(10, 7))
plt.show()

# %% [markdown]
# Combine both of the previous two plots into one

# %%
pm.plot(x = "defense", y = "attack", kind = "scatter", c=colors, s = pm.speed, alpha=.4)
plt.show()

# %% [markdown]
# ### Grouped plot: boxes and bars

# %% [markdown]
# Grouped box plots

# %%
#Use pandas to make box plot of the total column
pm.total.plot(kind="box")
plt.show()

# %%
pm.head()
# Out:
#                     name type_1  type_2  total  hp  attack  defense  sp_atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49      65
# 1                Ivysaur  Grass  Poison    405  60      62       63      80
# 2               Venusaur  Grass  Poison    525  80      82       83     100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123     122
# 4             Charmander   Fire     NaN    309  39      52       43      60
#
#    sp_def  speed  generation  legendary
# 0      65     45           1      False
# 1      80     60           1      False
# 2     100     80           1      False
# 3     120     80           1      False
# 4      50     65           1      False

# %%
#Box plot of attack points grouped by type_1
#Column is set equal to the continuous variable we wish to display
#By is set equal to the categorical variable that determines the various individual boxplots
plt.figure(figsize=(8, 8))
pm.boxplot(column = "total", by = "generation")
plt.tight_layout()
plt.show()

# %% [markdown]
# Grouped bar plots

# %%
#List of columns to use for this exercise
cols = ["hp", "attack", "defense"]

# %%
#Group by generation
#Pass in cols
#Call .mean()
#Call .plot() with bar plot and size of 10x8
#Set title to "Grouped Bar Plots"
pm.groupby("generation")[cols].mean().plot(kind = "bar", figsize = (10, 8), 
                                                        title = "Grouped Bar Plots")                                  
plt.show()

# %% [markdown]
# Stack 'em

# %%
#Same code as above but set stacked = True
pm.groupby("generation")[cols].mean().plot(kind = "bar", figsize = (10, 8), stacked = True,
                                                        title = "Grouped Bar Plots")
#Move legend box to center right
plt.legend(loc="right")
plt.show()

# %% [markdown]
# Which type of bar plot do you prefer? The stacked or the side by side? Why?

# %% [markdown]
# ## More resources on plotting in Python
#
# https://github.com/matplotlib/AnatomyOfMatplotlib/blob/master/AnatomyOfMatplotlib-Part1-Figures_Subplots_and_layouts.ipynb
#
# https://github.com/rasbt/matplotlib-gallery/tree/master/ipynb
#
# https://github.com/jbwhit/jupyter-tips-and-tricks/tree/master/notebooks
# <br><br>
# From [PythonDataScienceHandbook](https://github.com/jakevdp/PythonDataScienceHandbook):
#  - https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.00-Introduction-To-Matplotlib.ipynb
#  - https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.01-Simple-Line-Plots.ipynb
#  - https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.02-Simple-Scatter-Plots.ipynb
#  - https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.05-Histograms-and-Binnings.ipynb
#  - https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.04-Density-and-Contour-Plots.ipynb
#
#
#
# Check out the matplotlib cheat sheet in the extracurricular directory.

# %% [markdown]
# ## Class exercise
#
# Pick out a dataset from the data directory and explore it as much as possible using the visualizations we just learned. I want this to be a freeform exercise where you go out in the wild and explore on your own.
#
# You can choose any dataset you like but I recommend:
# - auto-mpg
# - red_wine_quality
# - simple_demographics
# - movie_metadata
# - drinks
#
# Everytime you make visualization, I want you to guess what you are going to see. Make an expectation and then see if you're proven wrong or right.
#
# Explore:
#     - The distributions of certain features (Histograms and bar plots)
#     - Use bar plots to count categorical data
#     - Relationships between different features. Do those relationships change when apply certain conditions

# %%
#Have fun!
path="../data/drinks.csv"

dk = pd.read_csv(path)

# %%
dk.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
cols = ["beer_servings", "spirit_servings", "wine_servings"]

# %%
dk.groupby("continent")[cols].mean().plot(kind = "bar", figsize = (10, 8), title = "Hello World");

# %%
dk.plot(x = "beer_servings", y = "wine_servings", kind = "scatter", alpha=.4)
plt.show()
